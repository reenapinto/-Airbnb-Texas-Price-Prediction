# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import geopandas as gpd

# %% [markdown]
# ### Step 1: Data Loading

# %%
#Calendar Table – Data Cleaning

# %%
# Data extraction
calendar = pd.read_csv('/kaggle/input/calender1/calendar.csv')
listings = pd.read_csv('/kaggle/input/listing1/listings.csv')
listings_extra = pd.read_csv('/kaggle/input/listing2/listings1.csv')
reviews = pd.read_csv('/kaggle/input/reviews/reviews.csv')
reviews_extra = pd.read_csv('/kaggle/input/reviews-2/reviews1.csv')
neighbourhoods = pd.read_csv('/kaggle/input/neighbourhoods/neighbourhoods.csv')
neighbourhoods_geo = gpd.read_file('/kaggle/input/neighbourhoods-geojson-1/neighbourhoods.geojson')

# %%
calendar.head()
# Out:
#    listing_id        date available  price  adjusted_price  minimum_nights  \
# 0        5456  2025-09-17         f    NaN             NaN               4
# 1        5456  2025-09-18         f    NaN             NaN               4
# 2        5456  2025-09-19         f    NaN             NaN               4
# 3        5456  2025-09-20         f    NaN             NaN               4
# 4        5456  2025-09-21         t    NaN             NaN               4
#
#    maximum_nights
# 0              90
# 1              90
# 2              90
# 3              90
# 4              90

# %%
calendar.describe()
# Out:
#          listing_id  price  adjusted_price  minimum_nights  maximum_nights
# count  3.844547e+06    0.0             0.0    3.844547e+06    3.844547e+06
# mean   7.673740e+17    NaN             NaN    8.303395e+00    8.469798e+06
# std    5.572091e+17    NaN             NaN    2.095058e+01    1.345945e+08
# min    5.456000e+03    NaN             NaN    1.000000e+00    1.000000e+00
# 25%    5.060361e+07    NaN             NaN    2.000000e+00    3.650000e+02
# 50%    8.952778e+17    NaN             NaN    2.000000e+00    3.650000e+02
# 75%    1.260918e+18    NaN             NaN    3.000000e+00    1.125000e+03
# max    1.510543e+18    NaN             NaN    9.150000e+02    2.147484e+09

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3844547 entries, 0 to 3844546
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           float64
#  4   adjusted_price  float64
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 205.3+ MB

# %%
calendar.isna().sum()
# Out:
# listing_id              0
# date                    0
# available               0
# price             3844547
# adjusted_price    3844547
# minimum_nights          0
# maximum_nights          0
# dtype: int64

# %%
calendar['available'] = (
    calendar['available']
    .map({'t': 1, 'f': 0})
    .astype('Int64')
)

# %%
non_null_counts = calendar.notna().sum()
non_null_counts
# Out:
# listing_id        3844547
# date              3844547
# available         3844547
# price                   0
# adjusted_price          0
# minimum_nights    3844547
# maximum_nights    3844547
# dtype: int64

# %%
# 1. Ensure correct data types
calendar['date'] = pd.to_datetime(calendar['date'], errors='coerce')

calendar['available'] = calendar['available'].astype(int)

calendar['minimum_nights'] = calendar['minimum_nights'].astype(int)
calendar['maximum_nights'] = calendar['maximum_nights'].astype(int)

# %%
#Visualize Outliers
calendar[['minimum_nights', 'maximum_nights']].quantile([0.95, 0.99])
# Out:
#       minimum_nights  maximum_nights
# 0.95            30.0          1125.0
# 0.99            90.0          1125.0

# %%
#Define Business Thresholds
MIN_NIGHTS_CAP = 90
MAX_NIGHTS_CAP = 1125

# %%
#Clean minimum_nights
calendar['minimum_nights_clean'] = calendar['minimum_nights'].clip(
    lower=1,
    upper=MIN_NIGHTS_CAP
)

# %%
#Clean maximum_nights
calendar['maximum_nights_clean'] = calendar['maximum_nights'].clip(
    lower=calendar['minimum_nights_clean'],
    upper=MAX_NIGHTS_CAP
)

# %%
#count= calendar[calendar[ 'maximum_nights_clean']>1125]
#count

# %%
calendar[['minimum_nights', 'maximum_nights','minimum_nights_clean', 'maximum_nights_clean']].describe()
# Out:
#        minimum_nights  maximum_nights  minimum_nights_clean  \
# count    3.844547e+06    3.844547e+06          3.844547e+06
# mean     8.303395e+00    8.469798e+06          7.608384e+00
# std      2.095058e+01    1.345945e+08          1.386686e+01
# min      1.000000e+00    1.000000e+00          1.000000e+00
# 25%      2.000000e+00    3.650000e+02          2.000000e+00
# 50%      2.000000e+00    3.650000e+02          2.000000e+00
# 75%      3.000000e+00    1.125000e+03          3.000000e+00
# max      9.150000e+02    2.147484e+09          9.000000e+01
#
#        maximum_nights_clean
# count          3.844547e+06
# mean           6.259394e+02
# std            4.530474e+02
# min            1.000000e+00
# 25%            3.650000e+02
# 50%            3.650000e+02
# 75%            1.125000e+03
# max            1.125000e+03

# %% [markdown]
# MIN_NIGHTS_CAP = 90
#
# calendar = calendar[
#     calendar['minimum_nights'] <= MIN_NIGHTS_CAP
# ]

# %%
calendar= calendar.drop(columns=['price', 'adjusted_price'])

# %%
calendar.notnull().sum()
# Out:
# listing_id              3844547
# date                    3844547
# available               3844547
# minimum_nights          3844547
# maximum_nights          3844547
# minimum_nights_clean    3844547
# maximum_nights_clean    3844547
# dtype: int64

# %%
calendar.to_parquet('/kaggle/working/1cleaned_calendar.parquet')

# %%
# listings Table – Data Cleaning

# %%
listings.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   5456   https://www.airbnb.com/rooms/5456  20250916040734   2025-09-17
# 1   6448   https://www.airbnb.com/rooms/6448  20250916040734   2025-09-17
# 2   8502   https://www.airbnb.com/rooms/8502  20250916040734   2025-09-17
# 3  13035  https://www.airbnb.com/rooms/13035  20250916040734   2025-09-17
# 4  22828  https://www.airbnb.com/rooms/22828  20250916040734   2025-09-16
#
#         source                                               name  \
# 0  city scrape          Walk to 6th, Rainey St and Convention Ctr
# 1  city scrape  Secluded Studio @ Zilker - King Bed, Bright & ...
# 2  city scrape                            Woodland Studio Lodging
# 3  city scrape      Historic house in highly walkable East Austin
# 4  city scrape                 Garage Apartment central SE Austin
#
#                                          description  \
# 0  Great central  location for walking to Convent...
# 1  Clean, private space with everything you need ...
# 2  Studio rental on lower level of home located i...
# 3  Comfortable 2 bedroom/2 bathroom home very cen...
# 4  Fully furnished, centrally located, second sto...
#
#                                neighborhood_overview  \
# 0  My neighborhood is ideally located if you want...
# 1  The neighborhood is fun and funky (but quiet)!...
# 2                                                NaN
# 3  East Cesar Chavez is a gentrifying urban area ...
# 4    wikipedia: East_Riverside-Oltorf,_Austin,_Texas
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/14084884/b5a3...     8028  ...
# 1  https://a0.muscache.com/pictures/airflow/Hosti...    14156  ...
# 2  https://a0.muscache.com/pictures/miso/Hosting-...    25298  ...
# 3  https://a0.muscache.com/pictures/miso/Hosting-...    50793  ...
# 4  https://a0.muscache.com/pictures/miso/Hosting-...    56488  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.82                   4.73                4.79
# 1                        4.98                   4.97                4.88
# 2                        4.88                   4.69                4.63
# 3                        5.00                   5.00                4.95
# 4                        5.00                   4.72                4.84
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              1
# 1     NaN                t                              1
# 2     NaN                f                              1
# 3     NaN                f                              2
# 4     NaN                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           1
# 2                                           1
# 3                                           2
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              3.52
# 1                                           0              1.98
# 2                                           0              0.28
# 3                                           0              0.11
# 4                                           0              0.30
#
# [5 rows x 79 columns]

# %%
listings.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  1.053300e+04  1.053300e+04  1.053300e+04         10524.000000
# mean   7.673744e+17  2.025092e+13  2.051309e+08           114.136830
# std    5.572353e+17  1.828212e+00  2.125070e+08           563.994257
# min    5.456000e+03  2.025092e+13  2.300000e+01             1.000000
# 25%    5.060361e+07  2.025092e+13  2.192214e+07             1.000000
# 50%    8.952778e+17  2.025092e+13  1.091668e+08             3.000000
# 75%    1.260918e+18  2.025092e+13  3.972112e+08            18.000000
# max    1.510543e+18  2.025092e+13  7.181423e+08          5030.000000
#
#        host_total_listings_count  neighbourhood_cleansed  \
# count               10524.000000            10533.000000
# mean                  165.268814            78724.782683
# std                   787.656139               20.868113
# min                     1.000000            78701.000000
# 25%                     2.000000            78704.000000
# 50%                     5.000000            78723.000000
# 75%                    26.000000            78745.000000
# max                  9684.000000            78759.000000
#
#        neighbourhood_group_cleansed      latitude     longitude  accommodates  \
# count                           0.0  10533.000000  10533.000000  10533.000000
# mean                            NaN     30.281656    -97.749225      5.334188
# std                             NaN      0.065631      0.064934      3.636149
# min                             NaN     30.078440    -98.053350      1.000000
# 25%                             NaN     30.242391    -97.767457      2.000000
# 50%                             NaN     30.269836    -97.739867      4.000000
# 75%                             NaN     30.313840    -97.715320      6.000000
# max                             NaN     30.519400    -97.562440     16.000000
#
#        ...  review_scores_checkin  review_scores_communication  \
# count  ...            8909.000000                  8909.000000
# mean   ...               4.894308                     4.902264
# std    ...               0.277543                     0.264418
# min    ...               1.000000                     1.000000
# 25%    ...               4.900000                     4.900000
# 50%    ...               4.970000                     4.980000
# 75%    ...               5.000000                     5.000000
# max    ...               5.000000                     5.000000
#
#        review_scores_location  review_scores_value  license  \
# count             8909.000000          8909.000000      0.0
# mean                 4.825561             4.778510      NaN
# std                  0.284337             0.328332      NaN
# min                  1.000000             1.000000      NaN
# 25%                  4.780000             4.730000      NaN
# 50%                  4.900000             4.850000      NaN
# 75%                  5.000000             4.950000      NaN
# max                  5.000000             5.000000      NaN
#
#        calculated_host_listings_count  \
# count                    10533.000000
# mean                         9.856736
# std                         17.808890
# min                          1.000000
# 25%                          1.000000
# 50%                          2.000000
# 75%                          9.000000
# max                         96.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                 10533.000000
# mean                                      8.208677
# std                                      15.960760
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       2.000000
# 75%                                       7.000000
# max                                      96.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  10533.000000
# mean                                       1.005507
# std                                        4.483837
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                       42.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                 10533.000000        8909.000000
# mean                                      0.520554           1.742838
# std                                       5.553189           1.809563
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.430000
# 50%                                       0.000000           1.230000
# 75%                                       0.000000           2.510000
# max                                      60.000000          41.140000
#
# [8 rows x 46 columns]

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10533 entries, 0 to 10532
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            10533 non-null  int64
#  1   listing_url                                   10533 non-null  object
#  2   scrape_id                                     10533 non-null  int64
#  3   last_scraped                                  10533 non-null  object
#  4   source                                        10533 non-null  object
#  5   name                                          10533 non-null  object
#  6   description                                   10311 non-null  object
#  7   neighborhood_overview                         5360 non-null   object
#  8   picture_url                                   10533 non-null  object
#  9   host_id                                       10533 non-null  int64
#  10  host_url                                      10533 non-null  object
#  11  host_name                                     10524 non-null  object
#  12  host_since                                    10524 non-null  object
#  13  host_location                                 8658 non-null   object
#  14  host_about                                    6958 non-null   object
#  15  host_response_time                            9676 non-null   object
#  16  host_response_rate                            9676 non-null   object
#  17  host_acceptance_rate                          9975 non-null   object
#  18  host_is_superhost                             10133 non-null  object
#  19  host_thumbnail_url                            10524 non-null  object
#  20  host_picture_url                              10524 non-null  object
#  21  host_neighbourhood                            9697 non-null   object
#  22  host_listings_count                           10524 non-null  float64
#  23  host_total_listings_count                     10524 non-null  float64
#  24  host_verifications                            10524 non-null  object
#  25  host_has_profile_pic                          10524 non-null  object
#  26  host_identity_verified                        10524 non-null  object
#  27  neighbourhood                                 5360 non-null   object
#  28  neighbourhood_cleansed                        10533 non-null  int64
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      10533 non-null  float64
#  31  longitude                                     10533 non-null  float64
#  32  property_type                                 10533 non-null  object
#  33  room_type                                     10533 non-null  object
#  34  accommodates                                  10533 non-null  int64
#  35  bathrooms                                     10527 non-null  float64
#  36  bathrooms_text                                10501 non-null  object
#  37  bedrooms                                      10520 non-null  float64
#  38  beds                                          10524 non-null  float64
#  39  amenities                                     10533 non-null  object
#  40  price                                         10517 non-null  object
#  41  minimum_nights                                10533 non-null  int64
#  42  maximum_nights                                10533 non-null  int64
#  43  minimum_minimum_nights                        10527 non-null  float64
#  44  maximum_minimum_nights                        10527 non-null  float64
#  45  minimum_maximum_nights                        10527 non-null  float64
#  46  maximum_maximum_nights                        10527 non-null  float64
#  47  minimum_nights_avg_ntm                        10533 non-null  float64
#  48  maximum_nights_avg_ntm                        10533 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              10448 non-null  object
#  51  availability_30                               10533 non-null  int64
#  52  availability_60                               10533 non-null  int64
#  53  availability_90                               10533 non-null  int64
#  54  availability_365                              10533 non-null  int64
#  55  calendar_last_scraped                         10533 non-null  object
#  56  number_of_reviews                             10533 non-null  int64
#  57  number_of_reviews_ltm                         10533 non-null  int64
#  58  number_of_reviews_l30d                        10533 non-null  int64
#  59  availability_eoy                              10533 non-null  int64
#  60  number_of_reviews_ly                          10533 non-null  int64
#  61  estimated_occupancy_l365d                     10533 non-null  int64
#  62  estimated_revenue_l365d                       10517 non-null  float64
#  63  first_review                                  8909 non-null   object
#  64  last_review                                   8909 non-null   object
#  65  review_scores_rating                          8909 non-null   float64
#  66  review_scores_accuracy                        8909 non-null   float64
#  67  review_scores_cleanliness                     8909 non-null   float64
#  68  review_scores_checkin                         8909 non-null   float64
#  69  review_scores_communication                   8909 non-null   float64
#  70  review_scores_location                        8909 non-null   float64
#  71  review_scores_value                           8909 non-null   float64
#  72  license                                       0 non-null      float64
#  73  instant_bookable                              10533 non-null  object
#  74  calculated_host_listings_count                10533 non-null  int64
#  75  calculated_host_listings_count_entire_homes   10533 non-null  int64
#  76  calculated_host_listings_count_private_rooms  10533 non-null  int64
#  77  calculated_host_listings_count_shared_rooms   10533 non-null  int64
#  78  reviews_per_month                             8909 non-null   float64
# dtypes: float64(25), int64(21), object(33)
# memory usage: 6.3+ MB

# %%
listings
# Out:
#                         id                                       listing_url  \
# 0                     5456                 https://www.airbnb.com/rooms/5456
# 1                     6448                 https://www.airbnb.com/rooms/6448
# 2                     8502                 https://www.airbnb.com/rooms/8502
# 3                    13035                https://www.airbnb.com/rooms/13035
# 4                    22828                https://www.airbnb.com/rooms/22828
# ...                    ...                                               ...
# 10528  1509111840521525342  https://www.airbnb.com/rooms/1509111840521525342
# 10529  1509788889374663874  https://www.airbnb.com/rooms/1509788889374663874
# 10530  1510032268538948494  https://www.airbnb.com/rooms/1510032268538948494
# 10531  1510421017787311377  https://www.airbnb.com/rooms/1510421017787311377
# 10532  1510543330054750084  https://www.airbnb.com/rooms/1510543330054750084
#
#             scrape_id last_scraped       source  \
# 0      20250916040734   2025-09-17  city scrape
# 1      20250916040734   2025-09-17  city scrape
# 2      20250916040734   2025-09-17  city scrape
# 3      20250916040734   2025-09-17  city scrape
# 4      20250916040734   2025-09-16  city scrape
# ...               ...          ...          ...
# 10528  20250916040734   2025-09-16  city scrape
# 10529  20250916040734   2025-09-16  city scrape
# 10530  20250916040734   2025-09-17  city scrape
# 10531  20250916040734   2025-09-16  city scrape
# 10532  20250916040734   2025-09-16  city scrape
#
#                                                     name  \
# 0              Walk to 6th, Rainey St and Convention Ctr
# 1      Secluded Studio @ Zilker - King Bed, Bright & ...
# 2                                Woodland Studio Lodging
# 3          Historic house in highly walkable East Austin
# 4                     Garage Apartment central SE Austin
# ...                                                  ...
# 10528  East Austin Escape | Spacious Stylish Home w/G...
# 10529             King Bedroom | Shared Bath & Amenities
# 10530                                 Tranquilo y comodo
# 10531                           Quaint Clarksville Condo
# 10532  Warm and Cozy 1BD/1BA North Central ATX Apartment
#
#                                              description  \
# 0      Great central  location for walking to Convent...
# 1      Clean, private space with everything you need ...
# 2      Studio rental on lower level of home located i...
# 3      Comfortable 2 bedroom/2 bathroom home very cen...
# 4      Fully furnished, centrally located, second sto...
# ...                                                  ...
# 10528  Enjoy your stay in this modern-style East Aust...
# 10529  Spacious king bedroom with Smart TV and dedica...
# 10530  Enjoy the simplicity of this quiet and central...
# 10531  Charming studio apartment in historic Clarksvi...
# 10532  Your Austin home away from home! This cozy 400...
#
#                                    neighborhood_overview  \
# 0      My neighborhood is ideally located if you want...
# 1      The neighborhood is fun and funky (but quiet)!...
# 2                                                    NaN
# 3      East Cesar Chavez is a gentrifying urban area ...
# 4        wikipedia: East_Riverside-Oltorf,_Austin,_Texas
# ...                                                  ...
# 10528                                                NaN
# 10529                                                NaN
# 10530                                                NaN
# 10531                                                NaN
# 10532                                                NaN
#
#                                              picture_url    host_id  ...  \
# 0      https://a0.muscache.com/pictures/14084884/b5a3...       8028  ...
# 1      https://a0.muscache.com/pictures/airflow/Hosti...      14156  ...
# 2      https://a0.muscache.com/pictures/miso/Hosting-...      25298  ...
# 3      https://a0.muscache.com/pictures/miso/Hosting-...      50793  ...
# 4      https://a0.muscache.com/pictures/miso/Hosting-...      56488  ...
# ...                                                  ...        ...  ...
# 10528  https://a0.muscache.com/pictures/hosting/Hosti...  478009344  ...
# 10529  https://a0.muscache.com/pictures/hosting/Hosti...  115683639  ...
# 10530  https://a0.muscache.com/pictures/hosting/Hosti...  301397512  ...
# 10531  https://a0.muscache.com/pictures/hosting/Hosti...   36290514  ...
# 10532  https://a0.muscache.com/pictures/hosting/Hosti...  566566357  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            4.82                   4.73                4.79
# 1                            4.98                   4.97                4.88
# 2                            4.88                   4.69                4.63
# 3                            5.00                   5.00                4.95
# 4                            5.00                   4.72                4.84
# ...                           ...                    ...                 ...
# 10528                         NaN                    NaN                 NaN
# 10529                         NaN                    NaN                 NaN
# 10530                         NaN                    NaN                 NaN
# 10531                         NaN                    NaN                 NaN
# 10532                         NaN                    NaN                 NaN
#
#       license instant_bookable calculated_host_listings_count  \
# 0         NaN                f                              1
# 1         NaN                t                              1
# 2         NaN                f                              1
# 3         NaN                f                              2
# 4         NaN                f                              1
# ...       ...              ...                            ...
# 10528     NaN                f                             19
# 10529     NaN                t                              7
# 10530     NaN                f                              2
# 10531     NaN                f                              1
# 10532     NaN                f                              4
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               1
# 1                                               1
# 2                                               1
# 3                                               2
# 4                                               1
# ...                                           ...
# 10528                                          19
# 10529                                           5
# 10530                                           0
# 10531                                           1
# 10532                                           4
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
# ...                                            ...
# 10528                                            0
# 10529                                            2
# 10530                                            2
# 10531                                            0
# 10532                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              3.52
# 1                                               0              1.98
# 2                                               0              0.28
# 3                                               0              0.11
# 4                                               0              0.30
# ...                                           ...               ...
# 10528                                           0               NaN
# 10529                                           0               NaN
# 10530                                           0               NaN
# 10531                                           0               NaN
# 10532                                           0               NaN
#
# [10533 rows x 79 columns]

# %%
drop_cols = [
    'listing_url','scrape_id','source','picture_url',
    'host_url','host_thumbnail_url','host_picture_url',
    'neighbourhood','neighbourhood_group_cleansed',
    'bathrooms_text','calendar_updated','has_availability',
    'license'
]

listings.drop(columns=drop_cols, inplace=True)

# %%
date_cols = [
    'last_scraped','host_since','calendar_last_scraped',
    'first_review','last_review'
]

for col in date_cols:
    listings[col] = pd.to_datetime(listings[col], errors='coerce')

# %%
bool_cols = [
    'host_is_superhost','host_has_profile_pic',
    'host_identity_verified','instant_bookable'
]

for col in bool_cols:
    listings[col] = listings[col].map({'t':1, 'f':0})

# %%
pct_cols = ['host_response_rate','host_acceptance_rate']

for col in pct_cols:
    listings[col] = (
        listings[col]
        .str.replace('%','', regex=False)
        .astype(float)
    )

# %%
listings['price'] = (
    listings['price']
    .str.replace('[$,]','', regex=True)
    .astype(float)
)

# %%
num_fill = ['bathrooms', 'bedrooms', 'beds']

for col in num_fill:
    listings[col] = listings[col].fillna(listings[col].median())

# %%
MIN_NIGHTS_CAP = 365
MAX_NIGHTS_CAP = 1825

# %%
listings['minimum_nights'] = listings['minimum_nights'].clip(1, MIN_NIGHTS_CAP)
listings['maximum_nights'] = listings['maximum_nights'].clip(1, MAX_NIGHTS_CAP)

# %%
night_cols = [
    'minimum_maximum_nights','maximum_maximum_nights',
    'maximum_nights_avg_ntm'
]

for col in night_cols:
    listings.loc[listings[col] > 1_000_000, col] = np.nan

# %%
listings = listings[listings['amenities'] != '[]']

# %%
listings.info()
listings.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10531 entries, 0 to 10532
# Data columns (total 66 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            10531 non-null  int64
#  1   last_scraped                                  10531 non-null  datetime64[ns]
#  2   name                                          10531 non-null  object
#  3   description                                   10309 non-null  object
#  4   neighborhood_overview                         5360 non-null   object
#  5   host_id                                       10531 non-null  int64
#  6   host_name                                     10522 non-null  object
#  7   host_since                                    10522 non-null  datetime64[ns]
#  8   host_location                                 8656 non-null   object
#  9   host_about                                    6958 non-null   object
#  10  host_response_time                            9676 non-null   object
#  11  host_response_rate                            9676 non-null   float64
#  12  host_acceptance_rate                          9975 non-null   float64
#  13  host_is_superhost                             10131 non-null  float64
#  14  host_neighbourhood                            9696 non-null   object
#  15  host_listings_count                           10522 non-null  float64
#  16  host_total_listings_count                     10522 non-null  float64
#  17  host_verifications                            10522 non-null  object
#  18  host_has_profile_pic                          10522 non-null  float64
#  19  host_identity_verified                        10522 non-null  float64
#  20  neighbourhood_cleansed                        10531 non-null  int64
#  21  latitude                                      10531 non-null  float64
#  22  longitude                                     10531 non-null  float64
#  23  property_type                                 10531 non-null  object
#  24  room_type                                     10531 non-null  object
#  25  accommodates                                  10531 non-null  int64
#  26  bathrooms                                     10531 non-null  float64
#  27  bedrooms                                      10531 non-null  float64
#  28  beds                                          10531 non-null  float64
#  29  amenities                                     10531 non-null  object
#  30  price                                         10515 non-null  float64
#  31  minimum_nights                                10531 non-null  int64
#  32  maximum_nights                                10531 non-null  int64
#  33  minimum_minimum_nights                        10525 non-null  float64
#  34  maximum_minimum_nights                        10525 non-null  float64
#  35  minimum_maximum_nights                        10525 non-null  float64
#  36  maximum_maximum_nights                        10483 non-null  float64
#  37  minimum_nights_avg_ntm                        10531 non-null  float64
#  38  maximum_nights_avg_ntm                        10489 non-null  float64
#  39  availability_30                               10531 non-null  int64
#  40  availability_60                               10531 non-null  int64
#  41  availability_90                               10531 non-null  int64
#  42  availability_365                              10531 non-null  int64
#  43  calendar_last_scraped                         10531 non-null  datetime64[ns]
#  44  number_of_reviews                             10531 non-null  int64
#  45  number_of_reviews_ltm                         10531 non-null  int64
#  46  number_of_reviews_l30d                        10531 non-null  int64
#  47  availability_eoy                              10531 non-null  int64
#  48  number_of_reviews_ly                          10531 non-null  int64
#  49  estimated_occupancy_l365d                     10531 non-null  int64
#  50  estimated_revenue_l365d                       10515 non-null  float64
#  51  first_review                                  8909 non-null   datetime64[ns]
#  52  last_review                                   8909 non-null   datetime64[ns]
#  53  review_scores_rating                          8909 non-null   float64
#  54  review_scores_accuracy                        8909 non-null   float64
#  55  review_scores_cleanliness                     8909 non-null   float64
#  56  review_scores_checkin                         8909 non-null   float64
#  57  review_scores_communication                   8909 non-null   float64
#  58  review_scores_location                        8909 non-null   float64
#  59  review_scores_value                           8909 non-null   float64
#  60  instant_bookable                              10531 non-null  int64
#  61  calculated_host_listings_count                10531 non-null  int64
#  62  calculated_host_listings_count_entire_homes   10531 non-null  int64
#  63  calculated_host_listings_count_private_rooms  10531 non-null  int64
#  64  calculated_host_listings_count_shared_rooms   10531 non-null  int64
#  65  reviews_per_month                             8909 non-null   float64
# dtypes: datetime64[ns](5), float64(28), int64(21), object(12)
# memory usage: 5.4+ MB
#                   id                   last_scraped  \
# count   1.053100e+04                          10531
# unique           NaN                            NaN
# top              NaN                            NaN
# freq             NaN                            NaN
# mean    7.674156e+17  2025-09-16 11:01:24.436425984
# min     5.456000e+03            2025-09-16 00:00:00
# 25%     5.060465e+07            2025-09-16 00:00:00
# 50%     8.952778e+17            2025-09-16 00:00:00
# 75%     1.260939e+18            2025-09-17 00:00:00
# max     1.510543e+18            2025-09-17 00:00:00
# std     5.572286e+17                            NaN
#
#                                                      name  \
# count                                               10531
# unique                                              10296
# top     Wyndham Austin Resort|1BR/1BA King Bed w/ Gym&...
# freq                                                   40
# mean                                                  NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# std                                                   NaN
#
#                                               description  \
# count                                               10309
# unique                                               9140
# top     Please click on -show more- and read the descr...
# freq                                                   42
# mean                                                  NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# std                                                   NaN
#
#                           neighborhood_overview       host_id     host_name  \
# count                                      5360  1.053100e+04         10522
# unique                                     4152           NaN          2588
# top     • CW Austin Resort is in Austin, Texas.           NaN  Vacasa Texas
# freq                                        112           NaN           131
# mean                                        NaN  2.051586e+08           NaN
# min                                         NaN  2.300000e+01           NaN
# 25%                                         NaN  2.190631e+07           NaN
# 50%                                         NaN  1.094553e+08           NaN
# 75%                                         NaN  3.973055e+08           NaN
# max                                         NaN  7.181423e+08           NaN
# std                                         NaN  2.125177e+08           NaN
#
#                            host_since host_location  \
# count                           10522          8656
# unique                            NaN           356
# top                               NaN    Austin, TX
# freq                              NaN          6778
# mean    2017-10-24 00:31:36.825698304           NaN
# min               2008-03-03 00:00:00           NaN
# 25%               2014-10-01 00:00:00           NaN
# 50%               2017-01-02 00:00:00           NaN
# 75%               2021-04-20 18:00:00           NaN
# max               2025-09-09 00:00:00           NaN
# std                               NaN           NaN
#
#                                                host_about  ...  \
# count                                                6958  ...
# unique                                               3137  ...
# top     Vacasa\nVacation Home Management\n\nVacasa unl...  ...
# freq                                                  123  ...
# mean                                                  NaN  ...
# min                                                   NaN  ...
# 25%                                                   NaN  ...
# 50%                                                   NaN  ...
# 75%                                                   NaN  ...
# max                                                   NaN  ...
# std                                                   NaN  ...
#
#        review_scores_checkin  review_scores_communication  \
# count            8909.000000                  8909.000000
# unique                   NaN                          NaN
# top                      NaN                          NaN
# freq                     NaN                          NaN
# mean                4.894308                     4.902264
# min                 1.000000                     1.000000
# 25%                 4.900000                     4.900000
# 50%                 4.970000                     4.980000
# 75%                 5.000000                     5.000000
# max                 5.000000                     5.000000
# std                 0.277543                     0.264418
#
#         review_scores_location  review_scores_value instant_bookable  \
# count              8909.000000          8909.000000     10531.000000
# unique                     NaN                  NaN              NaN
# top                        NaN                  NaN              NaN
# freq                       NaN                  NaN              NaN
# mean                  4.825561             4.778510         0.411072
# min                   1.000000             1.000000         0.000000
# 25%                   4.780000             4.730000         0.000000
# 50%                   4.900000             4.850000         0.000000
# 75%                   5.000000             4.950000         1.000000
# max                   5.000000             5.000000         1.000000
# std                   0.284337             0.328332         0.492052
#
#         calculated_host_listings_count  \
# count                     10531.000000
# unique                             NaN
# top                                NaN
# freq                               NaN
# mean                          9.858418
# min                           1.000000
# 25%                           1.000000
# 50%                           2.000000
# 75%                           9.000000
# max                          96.000000
# std                          17.810163
#
#         calculated_host_listings_count_entire_homes  \
# count                                  10531.000000
# unique                                          NaN
# top                                             NaN
# freq                                            NaN
# mean                                       8.210047
# min                                        0.000000
# 25%                                        1.000000
# 50%                                        2.000000
# 75%                                        7.000000
# max                                       96.000000
# std                                       15.961966
#
#        calculated_host_listings_count_private_rooms  \
# count                                  10531.000000
# unique                                          NaN
# top                                             NaN
# freq                                            NaN
# mean                                       1.005697
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                       42.000000
# std                                        4.484241
#
#         calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                  10531.000000        8909.000000
# unique                                          NaN                NaN
# top                                             NaN                NaN
# freq                                            NaN                NaN
# mean                                       0.520653           1.742838
# min                                        0.000000           0.010000
# 25%                                        0.000000           0.430000
# 50%                                        0.000000           1.230000
# 75%                                        0.000000           2.510000
# max                                       60.000000          41.140000
# std                                        5.553711           1.809563
#
# [11 rows x 66 columns]

# %%
#Fix encoding artifacts
text_cols = ['name','description','neighborhood_overview','host_about']

for col in text_cols:
    listings[col] = (
        listings[col]
        .str.encode('latin1', errors='ignore')
        .str.decode('utf-8', errors='ignore')
    )
# Out:
# /tmp/ipykernel_55/2378765132.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listings[col] = (

# %%
#Your latitude/longitude should be Austin-bounded.
listings = listings[
    listings['latitude'].between(30.0, 30.6) &
    listings['longitude'].between(-98.0, -97.5)
]

# %%
#Normalize Amenities
listings['amenities_count'] = listings['amenities'].apply(
    lambda x: len(eval(x)) if isinstance(x, str) else 0
)

# %%
listings.columns
# Out:
# Index(['id', 'last_scraped', 'name', 'description', 'neighborhood_overview',
#        'host_id', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified',
#        'neighbourhood_cleansed', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
#        'amenities', 'price', 'minimum_nights', 'maximum_nights',
#        'minimum_minimum_nights', 'maximum_minimum_nights',
#        'minimum_maximum_nights', 'maximum_maximum_nights',
#        'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'calendar_last_scraped', 'number_of_reviews', 'number_of_reviews_ltm',
#        'number_of_reviews_l30d', 'availability_eoy', 'number_of_reviews_ly',
#        'estimated_occupancy_l365d', 'estimated_revenue_l365d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
#        'amenities_count'],
#       dtype='object')

# %%
#Host Portfolio Consistency Check
listings = listings[
    listings['calculated_host_listings_count'] ==
    listings[['calculated_host_listings_count_entire_homes',
              'calculated_host_listings_count_private_rooms',
              'calculated_host_listings_count_shared_rooms']].sum(axis=1)
]
listings
# Out:
#                         id last_scraped  \
# 0                     5456   2025-09-17
# 1                     6448   2025-09-17
# 2                     8502   2025-09-17
# 3                    13035   2025-09-17
# 4                    22828   2025-09-16
# ...                    ...          ...
# 10528  1509111840521525342   2025-09-16
# 10529  1509788889374663874   2025-09-16
# 10530  1510032268538948494   2025-09-17
# 10531  1510421017787311377   2025-09-16
# 10532  1510543330054750084   2025-09-16
#
#                                                     name  \
# 0              Walk to 6th, Rainey St and Convention Ctr
# 1      Secluded Studio @ Zilker - King Bed, Bright & ...
# 2                                Woodland Studio Lodging
# 3          Historic house in highly walkable East Austin
# 4                     Garage Apartment central SE Austin
# ...                                                  ...
# 10528  East Austin Escape | Spacious Stylish Home w/G...
# 10529             King Bedroom | Shared Bath & Amenities
# 10530                                 Tranquilo y comodo
# 10531                           Quaint Clarksville Condo
# 10532  Warm and Cozy 1BD/1BA North Central ATX Apartment
#
#                                              description  \
# 0      Great central  location for walking to Convent...
# 1      Clean, private space with everything you need ...
# 2      Studio rental on lower level of home located i...
# 3      Comfortable 2 bedroom/2 bathroom home very cen...
# 4      Fully furnished, centrally located, second sto...
# ...                                                  ...
# 10528  Enjoy your stay in this modern-style East Aust...
# 10529  Spacious king bedroom with Smart TV and dedica...
# 10530  Enjoy the simplicity of this quiet and central...
# 10531  Charming studio apartment in historic Clarksvi...
# 10532  Your Austin home away from home! This cozy 400...
#
#                                    neighborhood_overview    host_id  \
# 0      My neighborhood is ideally located if you want...       8028
# 1      The neighborhood is fun and funky (but quiet)!...      14156
# 2                                                    NaN      25298
# 3      East Cesar Chavez is a gentrifying urban area ...      50793
# 4        wikipedia: East_Riverside-Oltorf,_Austin,_Texas      56488
# ...                                                  ...        ...
# 10528                                                NaN  478009344
# 10529                                                NaN  115683639
# 10530                                                NaN  301397512
# 10531                                                NaN   36290514
# 10532                                                NaN  566566357
#
#           host_name host_since     host_location  \
# 0            Sylvia 2009-02-16        Austin, TX
# 1               Amy 2009-04-20        Austin, TX
# 2             Karen 2009-07-11        Austin, TX
# 3      Margaret Ann 2009-11-02        Austin, TX
# 4             David 2009-11-22        Austin, TX
# ...             ...        ...               ...
# 10528          Paul 2022-09-03               NaN
# 10529         Dayna 2017-02-09  Pflugerville, TX
# 10530    Luis Renan 2019-10-10        Austin, TX
# 10531          John 2015-06-20        Austin, TX
# 10532       Allison 2024-03-11        Austin, TX
#
#                                               host_about  ...  \
# 0      I am a licensed Real Estate Broker and owner o...  ...
# 1      We are a family of four (with teenagers, all o...  ...
# 2      I handle the reservations at the studio on the...  ...
# 3      We're a responsible, easygoing couple who enjo...  ...
# 4      Wyoming native living in Austin since 1996. I ...  ...
# ...                                                  ...  ...
# 10528                                                NaN  ...
# 10529                                                NaN  ...
# 10530                                                NaN  ...
# 10531                                                NaN  ...
# 10532                                                NaN  ...
#
#       review_scores_communication  review_scores_location  \
# 0                            4.82                    4.73
# 1                            4.98                    4.97
# 2                            4.88                    4.69
# 3                            5.00                    5.00
# 4                            5.00                    4.72
# ...                           ...                     ...
# 10528                         NaN                     NaN
# 10529                         NaN                     NaN
# 10530                         NaN                     NaN
# 10531                         NaN                     NaN
# 10532                         NaN                     NaN
#
#        review_scores_value  instant_bookable calculated_host_listings_count  \
# 0                     4.79                 0                              1
# 1                     4.88                 1                              1
# 2                     4.63                 0                              1
# 3                     4.95                 0                              2
# 4                     4.84                 0                              1
# ...                    ...               ...                            ...
# 10528                  NaN                 0                             19
# 10529                  NaN                 1                              7
# 10530                  NaN                 0                              2
# 10531                  NaN                 0                              1
# 10532                  NaN                 0                              4
#
#        calculated_host_listings_count_entire_homes  \
# 0                                                1
# 1                                                1
# 2                                                1
# 3                                                2
# 4                                                1
# ...                                            ...
# 10528                                           19
# 10529                                            5
# 10530                                            0
# 10531                                            1
# 10532                                            4
#
#        calculated_host_listings_count_private_rooms  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                                 0
# ...                                             ...
# 10528                                             0
# 10529                                             2
# 10530                                             2
# 10531                                             0
# 10532                                             0
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 0                                               0               3.52
# 1                                               0               1.98
# 2                                               0               0.28
# 3                                               0               0.11
# 4                                               0               0.30
# ...                                           ...                ...
# 10528                                           0                NaN
# 10529                                           0                NaN
# 10530                                           0                NaN
# 10531                                           0                NaN
# 10532                                           0                NaN
#
#        amenities_count
# 0                   26
# 1                   61
# 2                   12
# 3                   54
# 4                   43
# ...                ...
# 10528               37
# 10529               13
# 10530               13
# 10531               33
# 10532               37
#
# [10126 rows x 67 columns]

# %%
lower = listings['price'].quantile(0.01)
upper = listings['price'].quantile(0.99)

listings = listings[listings['price'].between(lower, upper)]

# %%
listings['price'].describe()
# Out:
# count    9946.000000
# mean      188.210235
# std       169.282207
# min        33.000000
# 25%        87.000000
# 50%       134.000000
# 75%       216.000000
# max      1149.000000
# Name: price, dtype: float64

# %%
listings.to_parquet("/kaggle/working/cleaned_listings1.parquet")

# %%
# 3) cleaning listings_extra table

# %%
listings_extra.head()
# Out:
#       id                                               name  host_id  \
# 0   5456          Walk to 6th, Rainey St and Convention Ctr     8028
# 1   6448  Secluded Studio @ Zilker - King Bed, Bright & ...    14156
# 2   8502                            Woodland Studio Lodging    25298
# 3  13035      Historic house in highly walkable East Austin    50793
# 4  22828                 Garage Apartment central SE Austin    56488
#
#       host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 0        Sylvia                  NaN          78702  30.26057  -97.73441
# 1           Amy                  NaN          78704  30.26034  -97.76487
# 2         Karen                  NaN          78741  30.23466  -97.73682
# 3  Margaret Ann                  NaN          78702  30.26098  -97.73072
# 4         David                  NaN          78741  30.23614  -97.73225
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt   97.0               2                708  2025-09-02
# 1  Entire home/apt  160.0               3                339  2025-08-20
# 2  Entire home/apt   38.0               4                 54  2025-05-05
# 3  Entire home/apt  145.0              15                 19  2025-07-31
# 4  Entire home/apt   58.0              30                 56  2025-08-16
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               3.52                               1               328
# 1               1.98                               1               316
# 2               0.28                               1                88
# 3               0.11                               2               321
# 4               0.30                               1               211
#
#    number_of_reviews_ltm  license
# 0                     25      NaN
# 1                     14      NaN
# 2                      1      NaN
# 3                      1      NaN
# 4                      3      NaN

# %%
#initial inspection
listings_extra.info()
listings_extra.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10533 entries, 0 to 10532
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              10533 non-null  int64
#  1   name                            10533 non-null  object
#  2   host_id                         10533 non-null  int64
#  3   host_name                       10524 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   10533 non-null  int64
#  6   latitude                        10533 non-null  float64
#  7   longitude                       10533 non-null  float64
#  8   room_type                       10533 non-null  object
#  9   price                           10517 non-null  float64
#  10  minimum_nights                  10533 non-null  int64
#  11  number_of_reviews               10533 non-null  int64
#  12  last_review                     8909 non-null   object
#  13  reviews_per_month               8909 non-null   float64
#  14  calculated_host_listings_count  10533 non-null  int64
#  15  availability_365                10533 non-null  int64
#  16  number_of_reviews_ltm           10533 non-null  int64
#  17  license                         0 non-null      float64
# dtypes: float64(6), int64(8), object(4)
# memory usage: 1.4+ MB
#                   id                                               name  \
# count   1.053300e+04                                              10533
# unique           NaN                                              10298
# top              NaN  Wyndham Austin Resort|1BR/1BA King Bed w/ Gym&...
# freq             NaN                                                 40
# mean    7.673744e+17                                                NaN
# std     5.572353e+17                                                NaN
# min     5.456000e+03                                                NaN
# 25%     5.060361e+07                                                NaN
# 50%     8.952778e+17                                                NaN
# 75%     1.260918e+18                                                NaN
# max     1.510543e+18                                                NaN
#
#              host_id     host_name  neighbourhood_group  neighbourhood  \
# count   1.053300e+04         10524                  0.0   10533.000000
# unique           NaN          2589                  NaN            NaN
# top              NaN  Vacasa Texas                  NaN            NaN
# freq             NaN           131                  NaN            NaN
# mean    2.051309e+08           NaN                  NaN   78724.782683
# std     2.125070e+08           NaN                  NaN      20.868113
# min     2.300000e+01           NaN                  NaN   78701.000000
# 25%     2.192214e+07           NaN                  NaN   78704.000000
# 50%     1.091668e+08           NaN                  NaN   78723.000000
# 75%     3.972112e+08           NaN                  NaN   78745.000000
# max     7.181423e+08           NaN                  NaN   78759.000000
#
#             latitude     longitude        room_type         price  \
# count   10533.000000  10533.000000            10533  10517.000000
# unique           NaN           NaN                4           NaN
# top              NaN           NaN  Entire home/apt           NaN
# freq             NaN           NaN             9078           NaN
# mean       30.281656    -97.749225              NaN    414.537701
# std         0.065631      0.064934              NaN   2896.807897
# min        30.078440    -98.053350              NaN      8.000000
# 25%        30.242391    -97.767457              NaN     86.000000
# 50%        30.269836    -97.739867              NaN    135.000000
# 75%        30.313840    -97.715320              NaN    226.000000
# max        30.519400    -97.562440              NaN  50000.000000
#
#         minimum_nights  number_of_reviews last_review  reviews_per_month  \
# count     10533.000000       10533.000000        8909        8909.000000
# unique             NaN                NaN         865                NaN
# top                NaN                NaN  2025-09-01                NaN
# freq               NaN                NaN         716                NaN
# mean          7.768157          55.858920         NaN           1.742838
# std          20.586238         104.276866         NaN           1.809563
# min           1.000000           0.000000         NaN           0.010000
# 25%           1.000000           2.000000         NaN           0.430000
# 50%           2.000000          17.000000         NaN           1.230000
# 75%           3.000000          62.000000         NaN           2.510000
# max         365.000000        1305.000000         NaN          41.140000
#
#         calculated_host_listings_count  availability_365  \
# count                     10533.000000      10533.000000
# unique                             NaN               NaN
# top                                NaN               NaN
# freq                               NaN               NaN
# mean                          9.856736        234.909238
# std                          17.808890        114.102467
# min                           1.000000          0.000000
# 25%                           1.000000        143.000000
# 50%                           2.000000        263.000000
# 75%                           9.000000        339.000000
# max                          96.000000        365.000000
#
#         number_of_reviews_ltm  license
# count            10533.000000      0.0
# unique                    NaN      NaN
# top                       NaN      NaN
# freq                      NaN      NaN
# mean                13.065698      NaN
# std                 18.844388      NaN
# min                  0.000000      NaN
# 25%                  1.000000      NaN
# 50%                  5.000000      NaN
# 75%                 19.000000      NaN
# max                396.000000      NaN

# %%
# Drop Non-Informative Columns
listings_extra.drop(
    columns=['neighbourhood_group', 'license'],
    inplace=True
)

# %%
#Handle Missing Categorical Values
listings_extra['host_name'].fillna('Unknown', inplace=True)
# Out:
# /tmp/ipykernel_55/3065443695.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   listings_extra['host_name'].fillna('Unknown', inplace=True)

# %%
#Convert Data Types
listings_extra['last_review'] = pd.to_datetime(
    listings_extra['last_review'], errors='coerce'
)

# %%
listings_extra = listings_extra[listings_extra['price'] > 0]
lower_cap = listings_extra['price'].quantile(0.01)
upper_cap = listings_extra['price'].quantile(0.99)
listings_extra['price'] = listings_extra['price'].clip(lower=lower_cap, upper=upper_cap)

# %%
listings_extra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10517 entries, 0 to 10532
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              10517 non-null  int64
#  1   name                            10517 non-null  object
#  2   host_id                         10517 non-null  int64
#  3   host_name                       10517 non-null  object
#  4   neighbourhood                   10517 non-null  int64
#  5   latitude                        10517 non-null  float64
#  6   longitude                       10517 non-null  float64
#  7   room_type                       10517 non-null  object
#  8   price                           10517 non-null  float64
#  9   minimum_nights                  10517 non-null  int64
#  10  number_of_reviews               10517 non-null  int64
#  11  last_review                     8901 non-null   datetime64[ns]
#  12  reviews_per_month               8901 non-null   float64
#  13  calculated_host_listings_count  10517 non-null  int64
#  14  availability_365                10517 non-null  int64
#  15  number_of_reviews_ltm           10517 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(8), object(3)
# memory usage: 1.4+ MB

# %%
#Handle Review-Related Missing Values
listings_extra['reviews_per_month'].fillna(0, inplace=True)
listings_extra['has_reviews'] = listings_extra['last_review'].notna().astype(int)
# Out:
# /tmp/ipykernel_55/3594629934.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   listings_extra['reviews_per_month'].fillna(0, inplace=True)

# %%
listings_extra = listings_extra[
    (listings_extra['minimum_nights'] >= 1) &
    (listings_extra['minimum_nights'] <= 365)
]

listings_extra = listings_extra[
    listings_extra['availability_365'].between(0, 365)
]

# %%
listings_extra = listings_extra[
    listings_extra['latitude'].between(29, 31) &
    listings_extra['longitude'].between(-99, -96)
]

# %%
listings_extra.drop_duplicates(subset='id', inplace=True)

# %%
listings_extra.info()
listings_extra.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10517 entries, 0 to 10532
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              10517 non-null  int64
#  1   name                            10517 non-null  object
#  2   host_id                         10517 non-null  int64
#  3   host_name                       10517 non-null  object
#  4   neighbourhood                   10517 non-null  int64
#  5   latitude                        10517 non-null  float64
#  6   longitude                       10517 non-null  float64
#  7   room_type                       10517 non-null  object
#  8   price                           10517 non-null  float64
#  9   minimum_nights                  10517 non-null  int64
#  10  number_of_reviews               10517 non-null  int64
#  11  last_review                     8901 non-null   datetime64[ns]
#  12  reviews_per_month               10517 non-null  float64
#  13  calculated_host_listings_count  10517 non-null  int64
#  14  availability_365                10517 non-null  int64
#  15  number_of_reviews_ltm           10517 non-null  int64
#  16  has_reviews                     10517 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(9), object(3)
# memory usage: 1.4+ MB
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       1616
# reviews_per_month                    0
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# has_reviews                          0
# dtype: int64

# %%
listings_extra.to_parquet("cleaned_listings2.parquet")

# %%
# 4)cleaning reviews table

# %%
reviews.head()
# Out:
#    listing_id    id        date  reviewer_id       reviewer_name  \
# 0        5456   977  2009-03-19         8102                Phil
# 1        5456  1039  2009-03-22         8241               Galen
# 2        5456  1347  2009-04-08        11152               April
# 3        5456  1491  2009-04-13        12400              Ivonne
# 4        5456  1535  2009-04-16        11071  Egan.Sturges.Regan
#
#                                             comments
# 0  Highly recommended. Sylvia was extremely helpf...
# 1  A great place to stay in a great city. Sylvia ...
# 2  Highly recommended! \r<br/>Cute and cozy guest...
# 3  What a great little apartment!  It was clean, ...
# 4  Sylvia was great; "ditto" to all the previous ...

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588362 entries, 0 to 588361
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     588362 non-null  int64
#  1   id             588362 non-null  int64
#  2   date           588362 non-null  object
#  3   reviewer_id    588362 non-null  int64
#  4   reviewer_name  588361 non-null  object
#  5   comments       588182 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 26.9+ MB

# %%
reviews.describe(include='all')
# Out:
#           listing_id            id                           date  \
# count   5.883620e+05  5.883620e+05                         588362
# unique           NaN           NaN                            NaN
# top              NaN           NaN                            NaN
# freq             NaN           NaN                            NaN
# mean    3.037074e+17  7.544972e+17  2022-07-16 02:47:19.141889280
# min     5.456000e+03  9.770000e+02            2009-03-19 00:00:00
# 25%     1.710393e+07  7.379531e+08            2021-03-10 00:00:00
# 50%     4.193594e+07  8.710032e+17            2023-04-16 00:00:00
# 75%     6.984276e+17  1.225503e+18            2024-08-17 00:00:00
# max     1.507609e+18  1.511781e+18            2025-09-16 00:00:00
# std     4.461331e+17  5.329329e+17                            NaN
#
#          reviewer_id  reviewer_name     comments
# count   5.883620e+05       588362.0       588182
# unique           NaN            NaN       562806
# top              NaN            NaN  Great stay!
# freq             NaN            NaN         1120
# mean    1.902465e+08            1.0          NaN
# min     1.400000e+01            1.0          NaN
# 25%     4.362381e+07            1.0          NaN
# 50%     1.318087e+08            1.0          NaN
# 75%     3.134046e+08            1.0          NaN
# max     7.188310e+08            1.0          NaN
# std     1.751800e+08            0.0          NaN

# %%
reviews['date'] = pd.to_datetime(reviews['date'], errors='coerce')

# %%
#Clean Review Text (comments)
reviews['comments'] = (
    reviews['comments']
    .astype(str)
    .str.replace(r'<.*?>', '', regex=True)
    .str.strip()
)

# %%
# downloading the clean table
reviews.to_parquet("cleaned_reviews1.parquet")

# %%
# 5)cleaning reviews_extra table

# %%
reviews_extra.head()
# Out:
#    listing_id        date
# 0        5456  2009-03-19
# 1        5456  2009-03-22
# 2        5456  2009-04-08
# 3        5456  2009-04-13
# 4        5456  2009-04-16

# %%
reviews_extra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 584430 entries, 0 to 588361
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   listing_id  584430 non-null  int64
#  1   date        584430 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 13.4+ MB

# %%
reviews_extra.describe(include='all')
# Out:
#           listing_id        date
# count   5.883620e+05      588362
# unique           NaN        5138
# top              NaN  2025-04-06
# freq             NaN        1338
# mean    3.037074e+17         NaN
# std     4.461331e+17         NaN
# min     5.456000e+03         NaN
# 25%     1.710393e+07         NaN
# 50%     4.193594e+07         NaN
# 75%     6.984276e+17         NaN
# max     1.507609e+18         NaN

# %%
# Inspect duplicates
reviews_extra.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Drop full duplicates
reviews_extra = reviews_extra.drop_duplicates()

# %%
reviews_extra = reviews_extra[
    reviews_extra['listing_id'].notna() &
    (reviews_extra['listing_id'] > 0)
]

# %%
reviews_extra.to_parquet(
    "Cleaned_Reviews_Extra.parquet",
    index=False
)

# %%
# 6)cleaning neighbourhoods table

# %%
neighbourhoods.head()
# Out:
#    neighbourhood_group  neighbourhood
# 0                  NaN          78701
# 1                  NaN          78702
# 2                  NaN          78703
# 3                  NaN          78704
# 4                  NaN          78705

# %%
neighbourhoods.describe()
# Out:
#        neighbourhood_group  neighbourhood
# count                  0.0      44.000000
# mean                   NaN   78733.750000
# std                    NaN      16.421944
# min                    NaN   78701.000000
# 25%                    NaN   78723.750000
# 50%                    NaN   78734.500000
# 75%                    NaN   78747.250000
# max                    NaN   78759.000000

# %%
neighbourhoods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   neighbourhood_group  0 non-null      float64
#  1   neighbourhood        44 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 836.0 bytes

# %%
neighbourhoods=neighbourhoods.drop(columns='neighbourhood_group')

# %%
neighbourhoods.to_parquet("cleaned_neighbourhoods.parquet", index=False)

# %%
# 7) Cleaning neighbourhoods_geo

# %%
neighbourhoods_geo.head()
# Out:
#   neighbourhood neighbourhood_group  \
# 0         78739                None
# 1         78754                None
# 2         78732                None
# 3         78737                None
# 4         78756                None
#
#                                             geometry
# 0  MULTIPOLYGON (((-97.89002 30.20941, -97.88929 ...
# 1  MULTIPOLYGON (((-97.63658 30.40265, -97.63754 ...
# 2  MULTIPOLYGON (((-97.87303 30.43806, -97.87335 ...
# 3  MULTIPOLYGON (((-98.01876 30.24166, -98.01617 ...
# 4  MULTIPOLYGON (((-97.72793 30.32905, -97.72761 ...

# %%
neighbourhoods_geo.describe(include='all')
# Out:
#        neighbourhood neighbourhood_group  \
# count             44                   0
# unique            44                   0
# top            78739                 NaN
# freq               1                 NaN
#
#                                                  geometry
# count                                                  44
# unique                                                 44
# top     MULTIPOLYGON (((-97.89002 30.209408, -97.88929...
# freq                                                    1

# %%
neighbourhoods_geo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   neighbourhood        44 non-null     object
#  1   neighbourhood_group  0 non-null      object
#  2   geometry             44 non-null     geometry
# dtypes: geometry(1), object(2)
# memory usage: 1.2+ KB

# %%
#Drop non-informative column
neighbourhoods_geo = neighbourhoods_geo.drop(columns=['neighbourhood_group'])

# %%
# Enforce correct data types
neighbourhoods_geo['neighbourhood'] = neighbourhoods_geo['neighbourhood'].astype(int)

# %%
#Validate geometry integrity
neighbourhoods_geo = neighbourhoods_geo[neighbourhoods_geo.is_valid]

# %%
#Set CRS (Coordinate Reference System
neighbourhoods_geo = neighbourhoods_geo.set_crs(epsg=4326, inplace=False)

# %%
neighbourhoods_geo.to_parquet('cleaned_neighbourhoods_geo.parquet', index=False)
